# %%
setwd('Homer_results/')

# %%
table1 <- read.csv('LMC_I_downregulated/knownResults_lmc_I_down.csv')
table2 <- read.csv('LMC_II_downregulated/knownResults_lmc_II_down.csv')
table3 <- read.csv('LMC_III_downregulated/knownResults_lmc_III_down.csv')
table4 <- read.csv('LMC_I_upregulated/knownResults_lmc_I_up.csv')
table5 <- read.csv('LMC_II_upregulated/knownResults_lmc_II_up.csv')
table6 <- read.csv('LMC_III_upregulated/knownResults_lmc_III_up.csv')

# %%
colnames(table1)[1] <- "Motif Name"	
colnames(table1)[2] <- "Consensus"	
colnames(table1)[3] <- "P-value"	
colnames(table1)[4] <- "Log P-value"	
colnames(table1)[5] <- "q-value (Benjamini)"	
colnames(table1)[6] <- "# of Target Sequences with Motif"	
colnames(table1)[7] <- "% of Target Sequences with Motif"	
colnames(table1)[8] <- "# of Background Sequences with Motif"	
colnames(table1)[9] <- "% of Background Sequences with Motif"

# %%
colnames(table2)[1] <- "Motif Name"	
colnames(table2)[2] <- "Consensus"	
colnames(table2)[3] <- "P-value"	
colnames(table2)[4] <- "Log P-value"	
colnames(table2)[5] <- "q-value (Benjamini)"	
colnames(table2)[6] <- "# of Target Sequences with Motif"	
colnames(table2)[7] <- "% of Target Sequences with Motif"	
colnames(table2)[8] <- "# of Background Sequences with Motif"	
colnames(table2)[9] <- "% of Background Sequences with Motif"

# %%
colnames(table3)[1] <- "Motif Name"	
colnames(table3)[2] <- "Consensus"	
colnames(table3)[3] <- "P-value"	
colnames(table3)[4] <- "Log P-value"	
colnames(table3)[5] <- "q-value (Benjamini)"	
colnames(table3)[6] <- "# of Target Sequences with Motif"	
colnames(table3)[7] <- "% of Target Sequences with Motif"	
colnames(table3)[8] <- "# of Background Sequences with Motif"	
colnames(table3)[9] <- "% of Background Sequences with Motif"

# %%
colnames(table4)[1] <- "Motif Name"	
colnames(table4)[2] <- "Consensus"	
colnames(table4)[3] <- "P-value"	
colnames(table4)[4] <- "Log P-value"	
colnames(table4)[5] <- "q-value (Benjamini)"	
colnames(table4)[6] <- "# of Target Sequences with Motif"	
colnames(table4)[7] <- "% of Target Sequences with Motif"	
colnames(table4)[8] <- "# of Background Sequences with Motif"	
colnames(table4)[9] <- "% of Background Sequences with Motif"

# %%
colnames(table5)[1] <- "Motif Name"	
colnames(table5)[2] <- "Consensus"	
colnames(table5)[3] <- "P-value"	
colnames(table5)[4] <- "Log P-value"	
colnames(table5)[5] <- "q-value (Benjamini)"	
colnames(table5)[6] <- "# of Target Sequences with Motif"	
colnames(table5)[7] <- "% of Target Sequences with Motif"	
colnames(table5)[8] <- "# of Background Sequences with Motif"	
colnames(table5)[9] <- "% of Background Sequences with Motif"

# %%
colnames(table6)[1] <- "Motif Name"	
colnames(table6)[2] <- "Consensus"	
colnames(table6)[3] <- "P-value"	
colnames(table6)[4] <- "Log P-value"	
colnames(table6)[5] <- "q-value (Benjamini)"	
colnames(table6)[6] <- "# of Target Sequences with Motif"	
colnames(table6)[7] <- "% of Target Sequences with Motif"	
colnames(table6)[8] <- "# of Background Sequences with Motif"	
colnames(table6)[9] <- "% of Background Sequences with Motif"

# %%
table1 <- table1[1:25, ]
table2 <- table2[1:25, ]
table3 <- table3[1:25, ]
table4 <- table4[1:25, ]
table5 <- table5[1:25, ]
table6 <- table6[1:25, ]

# %%
#removing redundant columns
table1 <- table1[-10, ]
table3 <- table1[-23, ]
table4 <- table4[-10, ]
table5 <- table5[-c(11, 13), ]

# %%
write.csv(table1,"lmc_I_downregulated_top20Homer_knownmotifs.csv")
write.csv(table2,"lmc_II_downregulated_top20Homer_knownmotifs.csv")
write.csv(table3,"lmc_III_downregulated_top20Homer_knownmotifs.csv")
write.csv(table4,"lmc_I_upregulated_top20Homer_knownmotifs.csv")
write.csv(table5,"lmc_II_upregulated_top20Homer_knownmotifs.csv")
write.csv(table6,"lmc_III_upregulated_top20Homer_knownmotifs.csv")
